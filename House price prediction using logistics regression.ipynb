# %%
# !pip install numpy pandas matplotlib scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
# Sample data for houses
data = {
    'Size': [1500, 1800, 2400, 3000, 3500, 1300, 1700, 2600, 2200, 1400],
    'Bedrooms': [3, 4, 3, 5, 4, 2, 3, 4, 3, 2],
    'Location': [1, 2, 2, 3, 3, 1, 1, 2, 3, 1],  # 1=suburb, 2=city, 3=metro
    'Price': [300000, 400000, 500000, 600000, 650000, 280000, 340000, 520000, 480000, 290000]
}

# Convert to DataFrame
df = pd.DataFrame(data)
df.head()
# Out:
#    Size  Bedrooms  Location   Price
# 0  1500         3         1  300000
# 1  1800         4         2  400000
# 2  2400         3         2  500000
# 3  3000         5         3  600000
# 4  3500         4         3  650000

# %%
# If price > 500000, it's expensive (1), else not (0)
df['Expensive'] = df['Price'].apply(lambda x: 1 if x > 500000 else 0)
df[['Price', 'Expensive']]
# Out:
#     Price  Expensive
# 0  300000          0
# 1  400000          0
# 2  500000          0
# 3  600000          1
# 4  650000          1
# 5  280000          0
# 6  340000          0
# 7  520000          1
# 8  480000          0
# 9  290000          0

# %%
# Features (independent variables)
X = df[['Size', 'Bedrooms', 'Location']]

# Target (dependent variable)
y = df['Expensive']

# %%
# 70% for training, 30% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
